# %%
# !gdown https://drive.google.com/file/d/10OWo4v3Op1UQe_rCQX-laToo9wffIPIp/view?usp=sharing --fuzzy
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=10OWo4v3Op1UQe_rCQX-laToo9wffIPIp
# To: /content/vlsp_sentiment_test.csv
# 100% 159k/159k [00:00<00:00, 88.6MB/s]

# %%
# !gdown https://drive.google.com/file/d/1CEC49GoeBrCBY3gTGoIFiW0YB5LOZXVb/view?usp=sharing --fuzzy
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1CEC49GoeBrCBY3gTGoIFiW0YB5LOZXVb
# To: /content/vlsp_sentiment_train.csv
# 100% 858k/858k [00:00<00:00, 86.3MB/s]

# %%
# !gdown https://drive.google.com/file/d/1d4hk9wBL_MYr0_XACe_67LgCooQYrThl/view?usp=sharing --fuzzy
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1d4hk9wBL_MYr0_XACe_67LgCooQYrThl
# From (redirected): https://drive.google.com/uc?id=1d4hk9wBL_MYr0_XACe_67LgCooQYrThl&confirm=t&uuid=dde2cf9a-57ce-48b1-85ff-beabcfbae1b8
# To: /content/vi-model-CBOW.bin
# 100% 699M/699M [00:07<00:00, 89.6MB/s]

# %%
# !pip install pyvi
# Out:
# Collecting pyvi
#   Downloading pyvi-0.1.1-py2.py3-none-any.whl (8.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 21.0 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from pyvi) (1.2.2)
# Collecting sklearn-crfsuite (from pyvi)
#   Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pyvi) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pyvi) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pyvi) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pyvi) (3.5.0)
# Collecting python-crfsuite>=0.8.3 (from sklearn-crfsuite->pyvi)
#   Downloading python_crfsuite-0.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.5 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from sklearn-crfsuite->pyvi) (1.16.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from sklearn-crfsuite->pyvi) (0.9.0)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.10/dist-packages (from sklearn-crfsuite->pyvi) (4.66.4)
# Installing collected packages: python-crfsuite, sklearn-crfsuite, pyvi
# Successfully installed python-crfsuite-0.9.10 pyvi-0.1.1 sklearn-crfsuite-0.3.6

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from string import digits
from collections import Counter
from pyvi import ViTokenizer
from gensim.models.word2vec import Word2Vec
from keras.utils import to_categorical
# %matplotlib inline

# %%
data_train = pd.read_csv("vlsp_sentiment_train.csv", sep='\t')
data_train.columns =['Class', 'Data']
data_test = pd.read_csv("vlsp_sentiment_test.csv", sep='\t')
data_test.columns =['Class', 'Data']

# %%
print(data_train.shape)
print(data_test.shape)
# Out:
# (5100, 2)
# (1050, 2)

# %%
labels = data_train.iloc[:, 0].values
reviews = data_train.iloc[:, 1].values

# %%
encoded_labels = []

for label in labels:
    if label == -1:
        encoded_labels.append([1,0,0])
    elif label == 0:
        encoded_labels.append([0,1,0])
    else:
        encoded_labels.append([0,0,1])

encoded_labels = np.array(encoded_labels)

# %%
reviews_processed = []
unlabeled_processed = []
for review in reviews:
    review_cool_one = ''.join([char for char in review if char not in digits])
    reviews_processed.append(review_cool_one)

# %%
#Use PyVi for Vietnamese word tokenizer
word_reviews = []
all_words = []
for review in reviews_processed:
    review = ViTokenizer.tokenize(review.lower())
    word_reviews.append(review.split())

# %%
EMBEDDING_DIM = 400 # how big is each word vector
MAX_VOCAB_SIZE = 10000 # how many unique words to use (i.e num rows in embedding vector)
MAX_SEQUENCE_LENGTH = 300 # max number of words in a comment to use

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

# %%
tokenizer = Tokenizer(num_words=MAX_VOCAB_SIZE, lower=True, char_level=False)
tokenizer.fit_on_texts(word_reviews)
sequences_train = tokenizer.texts_to_sequences(word_reviews)
word_index = tokenizer.word_index

# %%
data = pad_sequences(sequences_train, maxlen=MAX_SEQUENCE_LENGTH)
labels = encoded_labels

# %%
print('Shape of X train and X validation tensor:',data.shape)
print('Shape of label train and validation tensor:', labels.shape)
# Out:
# Shape of X train and X validation tensor: (5100, 300)
# Shape of label train and validation tensor: (5100, 3)

# %%
import gensim
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess

from gensim.models.keyedvectors import KeyedVectors

word_vectors = KeyedVectors.load_word2vec_format('vi-model-CBOW.bin', binary=True)


vocabulary_size=min(len(word_index)+1,MAX_VOCAB_SIZE)
embedding_matrix = np.zeros((vocabulary_size, EMBEDDING_DIM))
print("vocab size", vocabulary_size)
for word, i in word_index.items():
    if i>=MAX_VOCAB_SIZE:
        continue
    try:
        embedding_vector = word_vectors[word]
        embedding_matrix[i] = embedding_vector
    except KeyError:
        embedding_matrix[i]=np.random.normal(0,np.sqrt(0.25),EMBEDDING_DIM)

del(word_vectors)

from keras.layers import Embedding
embedding_layer = Embedding(vocabulary_size,
                            EMBEDDING_DIM,
                            weights=[embedding_matrix],
                            trainable=True)
# Out:
# vocab size 7919

# %%
from keras.models import Model
from keras.layers import *
from keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Reshape, Flatten,LSTM,GRU,Bidirectional
from keras.models import Model
from keras import regularizers
sequence_length = data.shape[1]
num_filters = 512
drop = 0.2

inputs = Input(shape=(sequence_length,))
embedding = embedding_layer(inputs)

################## LSTM ONLY ###############################
reshape = Reshape((sequence_length,EMBEDDING_DIM))(embedding)

################# SINGLE LSTM ####################
lstm_0 = Bidirectional(LSTM(num_filters))(reshape)

# YOU WANNA ADD MORE LSTM LAYERS? UNCOMMENT THIS #
# lstm_2 = LSTM(1024, return_sequences=True)(reshape)
# lstm_1 = LSTM(512, return_sequences=True)(lstm_2)
# lstm_0 = LSTM(256)(lstm_1)

dropout = Dropout(drop)(lstm_0)
output = Dense(units=3, activation='softmax',kernel_regularizer=regularizers.l2(0.01))(dropout)

# this creates a model that includes
model = Model(inputs, output)


adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, weight_decay=0.0)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 300)]             0
#
#  embedding (Embedding)       (None, 300, 400)          3167600
#
#  reshape (Reshape)           (None, 300, 400)          0
#
#  bidirectional (Bidirection  (None, 1024)              3739648
#  al)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense (Dense)               (None, 3)                 3075
#
# =================================================================
# Total params: 6910323 (26.36 MB)
# Trainable params: 6910323 (26.36 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
### IF YOU HAVE MODEL WEIGHT AND WANNA LOAD IT
#model.load_weights("model.h5")

# %%
#define callbacks
#early_stopping = EarlyStopping(monitor='val_loss', min_delta=0.01, patience=4, verbose=1)
#callbacks_list = [early_stopping]
callbacks_list = []

model.fit(data, labels, epochs= 100, batch_size=512, callbacks=callbacks_list, shuffle=True) # validation_split=0.2,
# Out:
# Epoch 1/100
# 10/10 [==============================] - 24s 1s/step - loss: 1.1338 - accuracy: 0.4310
# Epoch 2/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.9703 - accuracy: 0.5708
# Epoch 3/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.8712 - accuracy: 0.6392
# Epoch 4/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.8869 - accuracy: 0.6473
# Epoch 5/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.7507 - accuracy: 0.7122
# Epoch 6/100
# 10/10 [==============================] - 11s 1s/step - loss: 0.6531 - accuracy: 0.7590
# Epoch 7/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.5657 - accuracy: 0.7933
# Epoch 8/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.4622 - accuracy: 0.8439
# Epoch 9/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.4170 - accuracy: 0.8537
# Epoch 10/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.3481 - accuracy: 0.8980
# Epoch 11/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.2385 - accuracy: 0.9357
# Epoch 12/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.1607 - accuracy: 0.9665
# Epoch 13/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.1068 - accuracy: 0.9855
# Epoch 14/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.0805 - accuracy: 0.9945
# Epoch 15/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.0867 - accuracy: 0.9900
# Epoch 16/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.0734 - accuracy: 0.9945
# Epoch 17/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.0582 - accuracy: 0.9976
# Epoch 18/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.0499 - accuracy: 0.9984
# Epoch 19/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.0448 - accuracy: 0.9990
# Epoch 20/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.0403 - accuracy: 0.9990
# Epoch 21/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.0376 - accuracy: 0.9994
# Epoch 22/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.0350 - accuracy: 0.9996
# Epoch 23/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.0328 - accuracy: 0.9996
# Epoch 24/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0311 - accuracy: 1.0000
# Epoch 25/100
# 10/10 [==============================] - 12s 1s/step - loss: 0.0333 - accuracy: 0.9984
# Epoch 26/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0664 - accuracy: 0.9878
# Epoch 27/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0773 - accuracy: 0.9894
# Epoch 28/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0524 - accuracy: 0.9965
# Epoch 29/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0400 - accuracy: 0.9986
# Epoch 30/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0348 - accuracy: 0.9994
# Epoch 31/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0306 - accuracy: 0.9998
# Epoch 32/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0309 - accuracy: 0.9998
# Epoch 33/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0280 - accuracy: 0.9998
# Epoch 34/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0267 - accuracy: 0.9996
# Epoch 35/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0264 - accuracy: 0.9992
# Epoch 36/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0250 - accuracy: 0.9998
# Epoch 37/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0233 - accuracy: 1.0000
# Epoch 38/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 39/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 40/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 41/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 42/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 43/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 44/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 45/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 46/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 47/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 48/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.2270 - accuracy: 0.9451
# Epoch 49/100
# 10/10 [==============================] - 13s 1s/step - loss: 1.4723 - accuracy: 0.4651
# Epoch 50/100
# 10/10 [==============================] - 13s 1s/step - loss: 1.0305 - accuracy: 0.4884
# Epoch 51/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.8645 - accuracy: 0.6676
# Epoch 52/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.6868 - accuracy: 0.7527
# Epoch 53/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.5326 - accuracy: 0.8071
# Epoch 54/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.4040 - accuracy: 0.8625
# Epoch 55/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.3072 - accuracy: 0.9022
# Epoch 56/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.2237 - accuracy: 0.9380
# Epoch 57/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1657 - accuracy: 0.9604
# Epoch 58/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1228 - accuracy: 0.9771
# Epoch 59/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1145 - accuracy: 0.9763
# Epoch 60/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.1099 - accuracy: 0.9822
# Epoch 61/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0840 - accuracy: 0.9884
# Epoch 62/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0661 - accuracy: 0.9941
# Epoch 63/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0580 - accuracy: 0.9961
# Epoch 64/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0518 - accuracy: 0.9967
# Epoch 65/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0470 - accuracy: 0.9976
# Epoch 66/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0441 - accuracy: 0.9988
# Epoch 67/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0414 - accuracy: 0.9992
# Epoch 68/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0399 - accuracy: 0.9994
# Epoch 69/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0383 - accuracy: 0.9992
# Epoch 70/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0370 - accuracy: 0.9996
# Epoch 71/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0358 - accuracy: 0.9996
# Epoch 72/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0348 - accuracy: 0.9996
# Epoch 73/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0339 - accuracy: 0.9996
# Epoch 74/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0340 - accuracy: 0.9994
# Epoch 75/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0897 - accuracy: 0.9812
# Epoch 76/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0867 - accuracy: 0.9861
# Epoch 77/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0638 - accuracy: 0.9924
# Epoch 78/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0496 - accuracy: 0.9978
# Epoch 79/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0452 - accuracy: 0.9980
# Epoch 80/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0429 - accuracy: 0.9984
# Epoch 81/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0378 - accuracy: 0.9990
# Epoch 82/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0345 - accuracy: 0.9994
# Epoch 83/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0331 - accuracy: 0.9996
# Epoch 84/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0315 - accuracy: 0.9996
# Epoch 85/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0307 - accuracy: 0.9996
# Epoch 86/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0301 - accuracy: 0.9996
# Epoch 87/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0290 - accuracy: 0.9996
# Epoch 88/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0283 - accuracy: 0.9998
# Epoch 89/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0279 - accuracy: 0.9996
# Epoch 90/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0274 - accuracy: 0.9998
# Epoch 91/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0269 - accuracy: 0.9998
# Epoch 92/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0265 - accuracy: 0.9996
# Epoch 93/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0260 - accuracy: 1.0000
# Epoch 94/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0255 - accuracy: 0.9996
# Epoch 95/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0249 - accuracy: 0.9998
# Epoch 96/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0245 - accuracy: 1.0000
# Epoch 97/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 98/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0237 - accuracy: 1.0000
# Epoch 99/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 100/100
# 10/10 [==============================] - 13s 1s/step - loss: 0.0241 - accuracy: 0.9996

# %%
labels_test = data_test.iloc[:, 0].values
reviews_test = data_test.iloc[:, 1].values

# %%
encoded_labels_test = []

for label_test in labels_test:
    if label_test == -1:
        encoded_labels_test.append([1,0,0])
    elif label_test == 0:
        encoded_labels_test.append([0,1,0])
    else:
        encoded_labels_test.append([0,0,1])

encoded_labels_test = np.array(encoded_labels_test)

# %%
reviews_processed_test = []
unlabeled_processed_test = []
for review_test in reviews_test:
    review_cool_one = ''.join([char for char in review_test if char not in digits])
    reviews_processed_test.append(review_cool_one)

# %%
#Use PyVi for Vietnamese word tokenizer
word_reviews_test = []
all_words = []
for review_test in reviews_processed_test:
    review_test = ViTokenizer.tokenize(review_test.lower())
    word_reviews_test.append(review_test.split())

# %%
sequences_test = tokenizer.texts_to_sequences(word_reviews_test)
data_test = pad_sequences(sequences_test, maxlen=MAX_SEQUENCE_LENGTH)
labels_test = encoded_labels_test

# %%
print('Shape of X train and X validation tensor:',data_test.shape)
print('Shape of label train and validation tensor:', labels_test.shape)
# Out:
# Shape of X train and X validation tensor: (1050, 300)
# Shape of label train and validation tensor: (1050, 3)

# %%
score = model.evaluate(data_test, labels_test)
# Out:
# 33/33 [==============================] - 2s 39ms/step - loss: 1.5450 - accuracy: 0.6838

# %%
print("%s: %.2f" % (model.metrics_names[0], score[0]))
print("%s: %.2f%%" % (model.metrics_names[1], score[1]*100))
# Out:
# loss: 1.55
# accuracy: 68.38%

# %%
# %cd /content
# Out:
# /content

# %%
model.save_weights("model.h5")

# %%
predictions = model.predict(data_test)
# Out:
# 33/33 [==============================] - 2s 35ms/step

# %%
predictions = predictions.argmax(axis = 1 )

# %%
labels_test_class = labels_test.argmax(axis = 1 )

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
mtrx = confusion_matrix(labels_test_class, predictions)

disp = ConfusionMatrixDisplay(confusion_matrix=mtrx,display_labels=[-1,0,1])
disp.plot()
